# %%
# 코랩 그래프에서 한글 설정 방법 

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 위 3줄 실행 후 Runtime - Restart - Runtime

#!pip install matplotlib

import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
plt.plot([1,2,3,4])  # y축 값으로 받는다. 
plt.show             # x축은 자동으로 생성
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'ro')

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.show
# ro 빨간색 red의 원형 'o'를 의미한다. 
# axis함수는 축의 범위를 지정. [xmin, xmax, ymin, ymax]
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'b-')
plt.axis([0,6,0,20])
plt.show
# b-는 파란색 blue의 실선 -을 의미한다. 
# axis함수는 축의 범위를 지정. [xmin, xmax, ymin, ymax]
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'gx')
plt.axis([0,6,0,20])
plt.show
# gx는 그린의 green의 x를 의미한다.
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'k*')
plt.axis([0,6,0,20])
plt.show
# k*은 블랙의 *를 의미한다.
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], ':c')
plt.axis([0,6,0,20])
plt.show
# :c은 cyan의 '점'를 의미한다.
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4],[1,4,9,16], '--y')
plt.axis([0,6,0,20])
plt.show
# --y는 노랑의 '대시'를 의미한다.
# Out:
# <function matplotlib.pyplot.show>

# %%
data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,3,5,10,8]}
plt.plot('data_x', 'data_y', data=data_dict)

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X축')
plt.ylabel('Y축')
# Out:
# Text(0, 0.5, 'Y축')

# %%
# 1교시 제출 
# 위 그래프를 삼각형의 magenta 색상으로 작성하여 제출 (구글 검색)

# %%
font1 = {'family':'serif',
         'color':'b',
         'weight':'bold',
         'size':14
         }

font2 = {'family':'fantasy',
         'color':'deeppink',
         'weight':'normal',
         'size':'xx-large'
         }

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
font1 = {'family':'serif',
         'color':'b',
         'weight':'bold',
         'size':14
         }

font2 = {'family':'fantasy',
         'color':'deeppink',
         'weight':'normal',
         'size':'xx-large',
         'rotation':0
         }

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.plot([1,2,3,4],[2,3,5,10], label = 'Pirce ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

# %%
plt.plot([1,2,3,4],[2,3,5,10], label = 'Pirce ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=8)

# %%
plt.plot([1,2,3,4],[2,3,5,10], label='Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label='Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2)

# %%
plt.plot([1,2,3,4],[2,3,5,10], label='Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label='Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2, fontsize=14)

# %%
plt.plot([1,2,3,4],[2,3,5,10], label='Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label='Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

# %%
plt.plot([1,2,3,4],[2,3,5,10], label='Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label='Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2, fontsize=14, frameon=False)

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.axis('scaled')
# Out:
# (0.85, 4.15, 1.6, 10.4)

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.axis('square')
# Out:
# (0.85, 9.65, 1.6, 10.4)

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %%
plt.plot([1,2,3,4],[2,3,5,10], 'bo--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
# 2교시 제출
# 역삼각형 마커와 점선으로 빨강색 그래프 
# plt.plot([1,2,3,4],[2,3,5,10])
# Y축 라벨을 세로로

# Y
# -
# A
# x
# i
# s

# %%
plt.plot([1,2,3,4],[2.0,2.5,3.3,4.5], 'r')
plt.plot([1,2,3,4],[2.0,2.8,4.3,6.5], 'g')
plt.plot([1,2,3,4],[2.0,3.0,5.0,10.0], 'b')

# %%
plt.plot([1,2,3,4],[2.0,2.5,3.3,4.5], color = 'springgreen')
plt.plot([1,2,3,4],[2.0,2.8,4.3,6.5], color = 'violet')
plt.plot([1,2,3,4],[2.0,3.0,5.0,10.0],color = 'dodgerblue')

# %%
plt.plot([1,2,3,4],[2,3,5,10], color='#e35f62', marker='o', linestyle='--')

# %%
x = [1,2,3,4]
y = [2,3,5,10]

plt.plot(x,y)

# %%
x = [1,2,3,4]
y = [2,3,5,10]

plt.plot(x,y)
plt.fill_betweenx(y[2:4],x[2:4], color='pink', alpha=0.5)

# %%
x = [1,2,3,4]
y = [2,3,5,10]

plt.plot(x,y)
plt.fill_between(x[1:3],y[1:3], alpha=0.5)

# %%
x = [1,2,3,4]
y1 = [2,3,5,10]
y2 = [1,2,4,8]

plt.plot(x,y1)  # x = [1,2,3,4]     y1 = [2,3,5,10]
plt.plot(x,y2)  # x = [1,2,3,4]     y1 = [1,2,4,8]

# %%
x = [1,2,3,4]
y1 = [2,3,5,10]
y2 = [1,2,4,8]

plt.plot(x,y1)  # x = [1,2,3,4]     y1 = [2,3,5,10]
plt.plot(x,y2)  # x = [1,2,3,4]     y1 = [1,2,4,8]

plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

# %%
# 3교시 미리 제출

# 위 그림에서 마지막 영역에 색강조 제출

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.arange(0,2,0.2) # 0부터 2 미만까지 0.2 씩 증가  
print(a)
plt.plot(a,a,'r--', a, a**2, 'bo', a, a**3, 'g-.')
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8]
# [<matplotlib.lines.Line2D at 0x7f03478a2710>,
#  <matplotlib.lines.Line2D at 0x7f03478a2910>,
#  <matplotlib.lines.Line2D at 0x7f03478a2a50>]

# %%
a = np.arange(0,2,0.2) # 0부터 2 미만까지 0.2 씩 증가 
 

# plt.plot(a,a,'r--', a, a**2, 'bo', a, a**3, 'g-.')
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)
plt.grid(True)

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)
plt.grid(True, axis='y')

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)
plt.grid(True, axis='x')

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

plt.xticks([0,1,2])
plt.yticks(np.arange(1,6))
# Out:
# ([<matplotlib.axis.YTick at 0x7f03476131d0>,
#   <matplotlib.axis.YTick at 0x7f03472d7ed0>,
#   <matplotlib.axis.YTick at 0x7f034733d990>,
#   <matplotlib.axis.YTick at 0x7f03472b0d90>,
#   <matplotlib.axis.YTick at 0x7f03472b0ed0>],
#  <a list of 5 Text major ticklabel objects>)

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

plt.xticks(np.arange(0,2,0.2))
#plt.yticks(np.arange(1,6))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

plt.xticks(np.arange(0,2,0.2), labels=['Jan','','Feb','','Mar','','May','','Jun','','Jul'])
#plt.yticks(np.arange(1,6))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

plt.xticks(np.arange(0,2,0.2), labels=['Jan','','Feb','','Mar','','May','','Jun','','Jul'])
plt.yticks(np.arange(0,7),('0','1GB','2GB','3GB','4GB','5GB','6GB'))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth = 2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize = 9)

plt.xticks(np.arange(0,2,0.2), labels=['Jan','','Feb','','Mar','','May','','Jun','','Jul'])
plt.yticks(np.arange(0,7),('0','1GB','2GB','3GB','4GB','5GB','6GB'))

plt.tick_params(axis='both', direction='out', 
                length=3, pad=6, labelsize=14, 
                labelcolor='green', bottom=True)


plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

plt.title('Graph Title')
plt.show()

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

plt.title('Graph Title', loc='right', pad=20)
plt.show()

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

title_font = {
    'fontsize':16,
    'fontweight':'bold'
}

plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
plt.show()

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

title_font = {
    'fontsize':16,
    'fontweight':'bold'
}

plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.axhline(1,0,0.55,color='gray', linestyle='--', linewidth='1')
plt.axvline(1,0,0.16,color='lightgray', linestyle=':', linewidth='2')

plt.axhline(5.83,0,0.95,color='gray', linestyle='--', linewidth='1')
plt.axvline(1.8,0,0.95,color='lightgray', linestyle=':', linewidth='2')


plt.show()

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a,a**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

title_font = {
    'fontsize':16,
    'fontweight':'bold'
}

plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.hlines(4,1,1.6, colors='pink', linewidth=3)
plt.vlines(1,1,4, colors='pink', linewidth=3)



plt.show()

# %%
x = np.arange(3)
years = ['2018','2019','2020']
values = [100,400,900]

plt.bar(x,values)
plt.xticks(x,years)

plt.show()

# %%
x = np.arange(3)
years = ['2018','2019','2020']
values = [100,400,900]

plt.bar(x,values, width=0.6, align='edge', color='forestgreen',
        edgecolor='gray', linewidth=3, 
        tick_label=years, log=True)
plt.xticks(x,years)

plt.show()

# %%
y = np.arange(3)
years = ['2018','2019','2020']
values = [100,400,900]

plt.barh(y,values)
plt.yticks(y,years)

plt.show()

# %%
y = np.arange(3)
years = ['2018','2019','2020']
values = [100,400,900]

plt.barh(y,values, height=-0.6, align='edge', color='forestgreen',
        edgecolor='gray', linewidth=3, 
        tick_label=years, log=False)

plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x,y)
plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 *np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x,y, s=area, c= colors)
plt.show()

# %%
plt.plot([1],[1], 'o',markersize = 20, c='#FF5733')
plt.scatter([2],[1], s=20**2, c='#33ffce')

plt.text(0.5,1.05,'Plot(markersize=20)', fontdict={'size': 14})
plt.text(1.6,1.05,'scatter(s=20**2)', fontdict={'size':14})
plt.axis([0.4,2.6,0.8,1.2])

plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n)) ** 2
colors = np.random.rand(n)

plt.scatter(x,y, s=area, c= colors, alpha=0.5, cmap='Spectral')
plt.colorbar()

plt.show()

# %%
np.random.seed(0)

n = 100
x = np.random.rand(n)
y = np.random.rand(n)
z = np.random.rand(n)
area = (15 * np.random.rand(n)) ** 2
colors = np.random.rand(n)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
    
    
ax.scatter(x,y,z, s=area, c= colors, cmap='jet')


plt.show()

# %%
np.random.seed(0)

arr = np.random.standard_normal((8,100))

plt.subplot(2,2,1)
plt.scatter(arr[0], arr[1], c=arr[1])
plt.spring()
plt.title('spring')
plt.colorbar()
plt.subplot(2,2,2)
plt.scatter(arr[2], arr[3], c=arr[3])
plt.summer()
plt.title('summer')
plt.colorbar()
plt.subplot(2,2,3)
plt.scatter(arr[4], arr[5], c=arr[5])
plt.autumn()
plt.title('autumn')
plt.colorbar()
plt.subplot(2,2,4)
plt.scatter(arr[6], arr[7], c=arr[7])
plt.winter()
plt.title('winter')

plt.colorbar()
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
cmaps = plt.colormaps()
for cm in cmaps:
  print(cm)
# Out:
# Accent
# Accent_r
# Blues
# Blues_r
# BrBG
# BrBG_r
# BuGn
# BuGn_r
# BuPu
# BuPu_r
# CMRmap
# CMRmap_r
# Dark2
# Dark2_r
# GnBu
# GnBu_r
# Greens
# Greens_r
# Greys
# Greys_r
# OrRd
# OrRd_r
# Oranges
# Oranges_r
# PRGn
# PRGn_r
# Paired
# Paired_r
# Pastel1
# Pastel1_r
# Pastel2
# Pastel2_r
# PiYG
# PiYG_r
# PuBu
# PuBuGn
# PuBuGn_r
# PuBu_r
# PuOr
# PuOr_r
# PuRd
# PuRd_r
# Purples
# Purples_r
# RdBu
# RdBu_r
# RdGy
# RdGy_r
# RdPu
# RdPu_r
# RdYlBu
# RdYlBu_r
# RdYlGn
# RdYlGn_r
# Reds
# Reds_r
# Set1
# Set1_r
# Set2
# Set2_r
# Set3
# Set3_r
# Spectral
# Spectral_r
# Wistia
# Wistia_r
# YlGn
# YlGnBu
# YlGnBu_r
# YlGn_r
# YlOrBr
# YlOrBr_r
# YlOrRd
# YlOrRd_r
# afmhot
# afmhot_r
# autumn
# autumn_r
# binary
# binary_r
# bone
# bone_r
# brg
# brg_r
# bwr
# bwr_r
# cividis
# cividis_r
# cool
# cool_r
# coolwarm
# coolwarm_r
# copper
# copper_r
# cubehelix
# cubehelix_r
# flag
# flag_r
# gist_earth
# gist_earth_r
# gist_gray
# gist_gray_r
# gist_heat
# gist_heat_r
# gist_ncar
# gist_ncar_r
# gist_rainbow
# gist_rainbow_r
# gist_stern
# gist_stern_r
# gist_yarg
# gist_yarg_r
# gnuplot
# gnuplot2
# gnuplot2_r
# gnuplot_r
# gray
# gray_r
# hot
# hot_r
# hsv
# hsv_r
# inferno
# inferno_r
# jet
# jet_r
# magma
# magma_r
# nipy_spectral
# nipy_spectral_r
# ocean
# ocean_r
# pink
# pink_r
# plasma
# plasma_r
# prism
# prism_r
# rainbow
# rainbow_r
# seismic
# seismic_r
# spring
# spring_r
# summer
# summer_r
# tab10
# tab10_r
# tab20
# tab20_r
# tab20b
# tab20b_r
# tab20c
# tab20c_r
# terrain
# terrain_r
# twilight
# twilight_r
# twilight_shifted
# twilight_shifted_r
# viridis
# viridis_r
# winter
# winter_r

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.randn(5000) - 10.0

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(1.0, 0.35, '2.0*np.random.randn(10000)+1.0')

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, 'np.random.standard_normal(10000)')

plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, 'np.random.rand(5000)-10.0')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.randn(5000)-10.0

font1 = {
         'family':'serif',
         'color':'darkred',
         'weight':'normal',
         'size':'16'
         }
font2 = {
         'family':'Times New Roman',
         'color':'blue',
         'weight':'bold',
         'size':'12'
         }
font3 = {
         'family':'Arial',
         'color':'forestgreen',
         'style':'italic',
         'size':'14'
         }

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(1.0, 0.35, 'np.random.randn()', fontdict=font1)

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, 'np.random.standard_normal()', fontdict=font2)

plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, 'np.random.rand()', fontdict=font3)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-10.0, 0.10, 'np.random.randn()', fontdict=font1, rotation=90)

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, 'np.random.stand.....', fontdict=font2, rotation=-80)

plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-60.0, 0.03, 'np.random.rand()', fontdict=font3)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
box1 = {'boxstyle':'round',
        'ec':(1.0,0.5,0.5),
        'fc':(1.0,0.8,0.8)}



plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-10.0, 0.10, 'np.random.randn()', fontdict=font1, rotation=90,bbox=box1)

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, 'np.random.stand.....', fontdict=font2, rotation=-80)

plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-60.0, 0.03, 'np.random.rand()', fontdict=font3)


box1 = {'boxstyle':'round',
        'ec':(1.0,0.5,0.5),  # edge color
        'fc':(1.0,0.8,0.8)}  # face color

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.text(1,15,r'$\alpha > \beta$', fontdict={'size':16})

plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

plt.text(1,15,r'$\alpha^2 > \beta_5$', fontdict={'size':16})

plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

plt.text(1,15,r'$\frac{1}{2} + \frac{3}{4} = \frac{5}{4}$', 
         fontdict={'size':16})

plt.savefig('savefig_default.png')

# %%
plt.figure(linewidth=2)

plt.plot([1,2,3,4],[1,4,9,16])

plt.text(1,15,r'$\frac{1}{2} + \frac{3}{4} = \frac{5}{4}$', 
         fontdict={'size':16})

plt.savefig('savefig_default_edge.png', facecolor='#eeeeee', edgecolor='blue')

# %%
fig, ax = plt.subplots() # 액자와 도화지를 동시
plt.show()

# %%
fig = plt.figure() # 액자
ax = fig.add_axes([0,0,1,1]) # 도화지
plt.show()

# %%
fig, ax = plt.subplots(2,2)   # 제출

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x))

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x))
ax[0][1].plot(x,x)

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x))
ax[0][1].plot(x,x)
ax[1][0].plot(x,-x+5)

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x))
ax[0][1].plot(x,x)
ax[1][0].plot(x,-x+5)
ax[1][1].plot(x,np.sqrt(-x+5))

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x), 'gray',linewidth=3)
ax[0][1].plot(x,x, 'g^-', markersize=10)
ax[1][0].plot(x,-x+5, 'ro--')
ax[1][1].plot(x,np.sqrt(-x+5),'b.-.')

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)

x = np.arange(1,5)

ax[0][0].plot(x,np.sqrt(x), 'gray',linewidth=3,
              label='y=np.sqrt(x)')
ax[0][0].set_title('Graph 1')
ax[0][0].legend()

ax[0][1].plot(x,x, 'g^-', markersize=10,
              label='y=x')
ax[0][1].set_title('Graph 2')
ax[0][1].legend()

ax[1][0].plot(x,-x+5, 'ro--',
              label='y=-x+5')
ax[1][0].set_title('Graph 3')
ax[1][0].legend()

ax[1][1].plot(x,np.sqrt(-x+5),'b.-.',
              label='y=np.sqart(-x+5)')
ax[1][1].set_title('Graph 4')
ax[1][1].legend()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['font.size'] = 12

x = np.arange(0,3)
y1 = x + 1
y2 = -x - 1

fig, ax1 = plt.subplots()
ax1.plot(x,y1,color='green')

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['font.size'] = 12

x = np.arange(0,3)
y1 = x + 1
y2 = -x - 1

fig, ax1 = plt.subplots()
ax1.plot(x,y1,color='green')

ax2 = ax1.twinx()
ax2.plot(x, y2, color='deeppink')


plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['font.size'] = 12

x = np.arange(2020,2027)
y1 = np.array([1,3,7,5,9,7,14])
y2 = np.array([1,3,5,7,9,11,13])

fig, ax1 = plt.subplots()

ax1.plot(x,y1,'-s', color='green', markersize=7, linewidth=5,
         alpha=0.7, label='Price')
ax1.set_ylim(0,18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction= 'in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', 
        label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0,18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis='both', direction= 'in')

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['font.size'] = 12

np.random.seed(0)
data_a = np.random.normal(0,2.0,1000)
data_b = np.random.normal(-3.0,1.5,1000)
data_c = np.random.normal(1.2,1.5,1500)

# %%
fig, ax = plt.subplots()

ax.boxplot([data_a, data_b, data_c], 
        notch=True, whis=2.5)
ax.set_ylim(-10.0, 10.0)
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
